# %%
import pandas as pd
import os
data_path = r"C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\raw\linkedin_leads.csv"

# %%
df = pd.read_csv(data_path)
df.head()
# Out:
#                                linkedinProfileUrl        fullName firstName  \
# 0   https://linkedin.com/in/mohamed-k-abdelmeguid  Mohamed Khaled   Mohamed
# 1   https://linkedin.com/in/emad-mounir-056137143     Emad Mounir      Emad
# 2          https://linkedin.com/in/mohammad-ashry  Mohammad Ashry  Mohammad
# 3  https://linkedin.com/in/moustafa-zein-65793444   Moustafa Zein  Moustafa
# 4             https://linkedin.com/in/hosamzewain    Hosam Zewain     Hosam
#
#   lastName         companyName                       linkedinCompanyUrl  \
# 0   Khaled                PALM  https://linkedin.com/company/withpalmai
# 1   Mounir             alfanar     https://linkedin.com/company/alfanar
# 2    Ashry  JATDEV Middle East      https://linkedin.com/company/jatdev
# 3     Zein                 NaN                                      NaN
# 4   Zewain          Appout ITS      https://linkedin.com/company/appout
#
#       linkedinJobTitle linkedinJobDateRange  \
# ...

# %%
# Out:
# Loading: C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\raw\linkedin_leads.csv
# Loading: C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\raw\phantombuster-all-leads-09072025 (1).csv
# Loading: C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\raw\phantombuster-all-leads-09072025 (3).csv
# Loading: C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\raw\phantombuster-all-leads-09072025 (5).csv
# ✅ Successfully concatenated 4 files. Total rows: 60
# 💾 Saved combined file to: C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\processed\combined_leads.csv

# %%
df = pd.read_csv(r"C:\Mohamed\Work\30 days projects\Ai-outreach-agent\data\raw\combined_leads.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   linkedinProfileUrl               40 non-null     object
#  1   fullName                         40 non-null     object
#  2   firstName                        40 non-null     object
#  3   lastName                         40 non-null     object
#  4   companyName                      38 non-null     object
#  5   linkedinCompanyUrl               38 non-null     object
#  6   linkedinJobTitle                 39 non-null     object
#  7   linkedinJobDateRange             39 non-null     object
#  8   companyIndustry                  38 non-null     object
#  9   linkedinHeadline                 40 non-null     object
#  10  location                         40 non-null     object
#  11  previousCompanyName              40 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['linkedinProfileUrl', 'fullName', 'firstName', 'lastName',
#        'companyName', 'linkedinCompanyUrl', 'linkedinJobTitle',
#        'linkedinJobDateRange', 'companyIndustry', 'linkedinHeadline',
#        'location', 'previousCompanyName', 'linkedinPreviousCompanyUrl',
#        'linkedinPreviousCompanySlug', 'linkedinPreviousJobTitle',
#        'linkedinPreviousJobDateRange', 'linkedinSchoolName',
#        'linkedinSchoolDegree', 'linkedinSchoolDateRange',
#        'linkedinPreviousSchoolName', 'linkedinPreviousSchoolDegree',
#        'linkedinPreviousSchoolDateRange', 'linkedinMutualConnectionsUrl',
#        'linkedinProfileSlug', 'linkedinCompanySlug', 'linkedinProfileUrn',
#        'id', 'connectionDegree', 'createdAt', 'updatedAt', 'createdBy',
#        'updatedBy'],
#       dtype='object')

# %%
filtered_columns = [
    "firstName" , "lastName" , "companyName"  , "linkedinCompanyUrl" , "linkedinJobTitle",
    "linkedinHeadline" , "companyIndustry" , "location" , "linkedinProfileUrl" , "linkedinJobDateRange"
]

df = df[df.columns.intersection(filtered_columns)]
df.head()
# Out:
#                                linkedinProfileUrl firstName lastName  \
# 0   https://linkedin.com/in/mohamed-k-abdelmeguid   Mohamed   Khaled
# 1   https://linkedin.com/in/emad-mounir-056137143      Emad   Mounir
# 2          https://linkedin.com/in/mohammad-ashry  Mohammad    Ashry
# 3  https://linkedin.com/in/moustafa-zein-65793444  Moustafa     Zein
# 4             https://linkedin.com/in/hosamzewain     Hosam   Zewain
#
#           companyName                       linkedinCompanyUrl  \
# 0                PALM  https://linkedin.com/company/withpalmai
# 1             alfanar     https://linkedin.com/company/alfanar
# 2  JATDEV Middle East      https://linkedin.com/company/jatdev
# 3                 NaN                                      NaN
# 4          Appout ITS      https://linkedin.com/company/appout
#
#       linkedinJobTitle linkedinJobDateRange  \
# 0  Head of Engineering   Jan 2025 - Present
# 1       Design Manager   Jan 2025 - Present
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   linkedinProfileUrl    40 non-null     object
#  1   firstName             40 non-null     object
#  2   lastName              40 non-null     object
#  3   companyName           38 non-null     object
#  4   linkedinCompanyUrl    38 non-null     object
#  5   linkedinJobTitle      39 non-null     object
#  6   linkedinJobDateRange  39 non-null     object
#  7   companyIndustry       38 non-null     object
#  8   linkedinHeadline      40 non-null     object
#  9   location              40 non-null     object
# dtypes: object(10)
# memory usage: 3.3+ KB

# %%
df = df.dropna(subset=["companyName"])

# %%
df["linkedinJobTitle"] = df["linkedinJobTitle"].fillna("Unknown Job Title")
df["linkedinCompanyUrl"] = df["linkedinCompanyUrl"].fillna("")
df["linkedinJobDateRange"] = df["linkedinJobDateRange"].fillna("")

# %%
df["firstName"] = df["firstName"].str.title()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 0 to 39
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   linkedinProfileUrl    38 non-null     object
#  1   firstName             38 non-null     object
#  2   lastName              38 non-null     object
#  3   companyName           38 non-null     object
#  4   linkedinCompanyUrl    38 non-null     object
#  5   linkedinJobTitle      38 non-null     object
#  6   linkedinJobDateRange  38 non-null     object
#  7   companyIndustry       38 non-null     object
#  8   linkedinHeadline      38 non-null     object
#  9   location              38 non-null     object
# dtypes: object(10)
# memory usage: 3.3+ KB
